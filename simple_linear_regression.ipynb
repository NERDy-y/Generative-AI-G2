# %% [markdown]
# <a href="https://colab.research.google.com/github/NERDy-y/Generative-AI-G2/blob/main/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/shoolini/placement (1).csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
#find number of rows and columns
df.shape
# Out:
# (200, 2)

# %%
#find the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
#find the null value in the data set
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
#find independant and dependant feature
x = df.iloc[:,0]
y = df.iloc[:,1]
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
# split the data itno train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
# 79     7.18
# 197    7.21
# 38     8.62
# 24     6.53
# 122    5.12
#        ...
# 106    6.13
# 14     7.73
# 92     7.90
# 179    7.14
# 102    5.13
# Name: cgpa, Length: 160, dtype: float64

# %%
# training the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
#intercept
b = model.intercept_
print(b)
# Out:
# -1.0270069374542108

# %%
# coefficient
m = model.coef_
print(m[0])
# Out:
# 0.5742564727019197

# %%
cgpa = 9.5
package = m*cgpa + b
print(package)
# Out:
# [4.42842955]

# %%
#testing th4e model
y_pred = model.predict(x_test.values.reshape(-1,1))
y_pred,y_test
# Out:
# (array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#         3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#         1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#         3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#         2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#         2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#         3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#         3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298]),
#  95     2.79
#  15     3.23
#  30     3.26
#  158    3.04
#  128    3.34
#  115    4.21
#  69     2.94
#  170    2.87
#  174    2.99
#  45     3.58
#  66     1.63
#  182    2.08
#  165    4.08
#  78     2.21
#  186    3.47
#  177    3.64
#  56     2.74
#  152    3.08
#  82     2.17
#  68     2.99
#  124    2.31
#  16     2.35
#  148    3.40
#  93     3.08
#  65     3.81
#  60     2.19
#  84     1.53
#  67     2.89
#  125    3.16
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["cgpa"],df["package"])
plt.plot(x_test,y_pred, color = "red")
plt.xlabel("cgpa")
plt.ylabel("package")
plt.show()
